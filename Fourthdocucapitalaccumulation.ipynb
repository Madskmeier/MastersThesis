# %%
# magics: ensures that any changes to the modules loaded below will be re-loaded automatically
# %load_ext autoreload
# %autoreload 2

# load general packages
import numpy as np
import matplotlib.pyplot as plt
plt.style.use('seaborn-whitegrid')
from mpl_toolkits.mplot3d import Axes3D
# load modules related to this exercise
import tools_Exercise_1_6 as tools
import Coronamacromodelcapitalaccumulation as ex6

# %%
#Simulatingbaseline
par41=ex6.setup()
par41.alt = 0
sol41 = ex6.solve_cons_inf(par41)
#simu41 =
# Out:
# 6988319395750295
# 4786278902.636306
# 0.16971331076638307
# 4786298348.858353
# 0.16954359745432157
# 4786317775.634179
# 0.16937405385397142
# 4786337182.983228
# 0.16920467980526155
# 4786356570.924928
# 0.16903547512629302
# 4786375939.478686
# 0.16886643965699477
# 4786395288.663892
# 0.1686975732081919
# 4786414618.499911
# 0.1685288756416412
# 4786433929.006095
# 0.16836034676089184
# 4786453220.201772
# 0.16819198642042466
# 4786472492.106253
# 0.16802379442378879
# 4786491744.738831
# 0.167855770640017
# 4786510978.118776
# 0.16768791486538248
# 4786530192.265341
# 0.16752022694709012
# 4786549387.197759
# 0.16735270672506886
# 4786568562.935244
# 0.16718535401014378
# 4786587719.496992
# 0.16701816865679575
# 4786606856.902178
# 0.16685115049040178
# 4786625975.16996
# 0.16668429933633888
# 4786645074.319473
# 0.166517615034536
# 4786664154.369837
# 0.16635109742492205
# 4786683215.340151
# 0.16618474631832214
# 4786702257.249494
# 0.16601856158376904
# 4786721280.116927
# ...

# %%
#Investigating effects of government lockdown - Smart lockdown aimed at keeping infections below 2 percent of population at any given point. Each lockdown set to last 60 days.
np.save('PolFG.npy', sol41.lw)
np.save('ValFG.npy', sol41.V)

# %%
par41.simN=720
par41.M_ini=1200
par41.I_ini=0.01
sim41  = ex6.simu(par41, sol41)
sim42 = ex6.simu_wl(par41, sol41)
sim43 = ex6.simu_sl(par41, sol41)
sim44 = ex6.simu_swl(par41, sol41)
# Out:
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 1246.9179053595458
# 1
# 1248.2673738940437
# 1
# 1249.5762454736966
# 1
# 1250.845739272811
# 1
# 1252.0770378278453
# 1
# 1253.2712881402322
# 1
# 1254.429602745968
# 1
# 1255.553060752971
# 1
# 1256.6427088471796
# 1
# 1257.6995622683282
# 1
# 1258.7246057563166
# 1
# 1259.7187944690572
# 1
# 1260.6830548726612
# 1
# 1261.618285604792
# 1
# 1262.5253583120007
# 1
# 1263.405118461823
# 1
# 1264.2583861303997
# 1
# 1265.0859567663592
# 1
# 1265.8886019316765
# 1
# 1266.6670700202026
# 1
# 1267.4220869545386
# 1
# 1268.1543568619081
# 1
# 1268.8645627296578
# 1
# 1269.5533670410043
# 1
# 1270.221412391623
# 1
# 1270.8693220876532
# 1
# 1271.4977007256837
# 1
# 1272.1071347552613
# 1
# 1272.69819302445
# 1
# 1273.2714273089498
# 1
# 1273.8273728252757
# 1
# 1274.3665487284732
# 1
# 1274.8894585948403
# 1
# 1275.3965908901068
# 1
# 1275.88841942351
# 1
# 1276.3654037881927
# 1
# 1276.827989788337
# 1
# 1277.2766098534314
# 1
# 1277.7116834400642
# ...

# %%
fig = plt.figure(figsize=(15,8))# figsize is in inches...

ax_right = fig.add_subplot(4,3,1)
ax_right.plot(sim41.grid, sim41.I, label='Baseline')
ax_right.plot(sim41.grid, sim42.I, label='Firm-sector lockdown')
ax_right.plot(sim41.grid, sim43.I, label='Social-lockdown')
#ax_right.plot(sim41.grid, sim44.I, label='Firm and Social-lockdown')
ax_right.set_xlabel(f"$Day$")
ax_right.set_ylabel(f"$Infected (I_t)$")
leg = ax_right.legend()

ax_right = fig.add_subplot(4,3,2)
ax_right.plot(sim41.grid, sim41.lw)
ax_right.plot(sim41.grid, sim42.lw)
ax_right.plot(sim41.grid, sim43.lw)
#ax_right.plot(sim41.grid, sim44.lw)
ax_right.set_xlabel(f"$Days$")
ax_right.set_ylabel(r"$Labor usage (L_{wt})$")

ax_right = fig.add_subplot(4,3,3)
ax_right.plot(sim41.grid, sim41.l)
ax_right.plot(sim41.grid, sim42.l)
ax_right.plot(sim41.grid, sim43.l)
#ax_right.plot(sim41.grid, sim44.l)
ax_right.set_xlabel(f"$Days$")
ax_right.set_ylabel(f"$Activity (l_t)$")

ax_right = fig.add_subplot(4,3,4)
ax_right.plot(sim41.grid, sim41.K)
ax_right.plot(sim41.grid, sim42.K)
ax_right.plot(sim41.grid, sim43.K)
ax_right.set_xlabel(f"$Days$")
ax_right.set_ylabel(f"$Capitalusage (K_t)$")

ax_right = fig.add_subplot(4,3,5)
ax_right.plot(sim41.grid, sim41.M)
ax_right.plot(sim41.grid, sim42.M)
ax_right.plot(sim41.grid, sim43.M)
#ax_right.plot(sim41.grid, sim44.M)
ax_right.set_xlabel(f"$Days$")
ax_right.set_ylabel(f"$Funds (M_t)$")

ax_right = fig.add_subplot(4,3,6)
ax_right.plot(sim41.grid, sim41.Y)
ax_right.plot(sim41.grid, sim42.Y)
ax_right.plot(sim41.grid, sim43.Y)
##3ax_right.plot(sim41.grid, sim44.Y)
ax_right.set_xlabel(f"$Days$")
ax_right.set_ylabel(f"$Production (Y_t)$")

ax_right = fig.add_subplot(4,3,7)
ax_right.plot(sim41.grid, sim41.c)
ax_right.plot(sim41.grid, sim42.c)
ax_right.plot(sim41.grid, sim43.c)
#ax_right.plot(sim41.grid, sim44.c)
ax_right.set_xlabel(f"$Day$")
ax_right.set_ylabel(f"$Spending on alternative good(c_t)$")

ax_right = fig.add_subplot(4,3,8)
ax_right.plot(sim41.grid, sim41.R)
ax_right.plot(sim41.grid, sim42.R)
ax_right.plot(sim41.grid, sim43.R)
##ax_right.plot(sim41.grid, sim44.R)
ax_right.set_xlabel(f"$Day$")
ax_right.set_ylabel(f"$Recovered (R_t)$")

ax_right = fig.add_subplot(4,3,9)
ax_right.plot(sim41.grid, sim41.p)
ax_right.plot(sim41.grid, sim42.p)
ax_right.plot(sim41.grid, sim43.p)
##ax_right.plot(sim41.grid, sim44.p)
ax_right.set_xlabel(f"$Day$")
ax_right.set_ylabel(f"$Price (p_t)$")

ax_right = fig.add_subplot(4,3,10)
ax_right.plot(sim41.grid, sim41.Q)
ax_right.plot(sim41.grid, sim42.Q)
ax_right.plot(sim41.grid, sim43.Q)
#ax_right.plot(sim41.grid, sim44.Q)
ax_right.set_xlabel(f"$Day$")
ax_right.set_ylabel(f"$Quarantined (Q_t)$")

ax_right = fig.add_subplot(4,3,11)
ax_right.plot(sim41.grid, sim41.pi)
ax_right.plot(sim41.grid, sim42.pi)
ax_right.plot(sim41.grid, sim43.pi)
#ax_right.plot(sim41.grid, sim44.pi)
ax_right.set_xlabel(f"$Day$")
ax_right.set_ylabel(r"$Profits (\Pi_t)$")

ax_right = fig.add_subplot(4,3,12)
ax_right.plot(sim41.grid, sim41.util)
ax_right.plot(sim41.grid, sim42.util)
ax_right.plot(sim41.grid, sim43.util)
#ax_right.plot(sim41.grid, sim44.Pos)
ax_right.set_xlabel(f"$Day$")
ax_right.set_ylabel(f"$Utility (U_t)$")

fig.savefig('lockdowns.png')

# %%
#print(sim41.p*sim41.Y)
print(min(sim41.p))
# Out:
# 0.9818919527934072

# %%
disc=ex6.discount(par41)
print((np.sum(disc.disc*sim41.pi)-np.sum(disc.disc*sim42.pi))/np.sum(disc.disc*sim41.pi))

print((np.sum(disc.disc*sim41.util)-np.sum(disc.disc*sim42.util))/np.sum(disc.disc*sim41.util))
# Out:
# 0.09898403782442662
# -0.28232482789850005

# %%
par42=ex6.setup()
par42.G=par42.Upsillon/par42.upsillon
sol42 = ex6.solve_cons_inf(par42)
# Out:
# 9767549491953
# 4795313980.577883
# 0.16962787781085353
# 4795333398.95211
# 0.1694582499403623
# 4795352797.907964
# 0.16928879168699495
# 4795372177.464862
# 0.16911950289068045
# 4795391537.642202
# 0.1689503833913477
# 4795410878.459368
# 0.16878143301437376
# 4795430199.935714
# 0.1686126515705837
# 4795449502.090583
# 0.16844403891445836
# 4795468784.943299
# 0.16827559487865074
# 4795488048.513161
# 0.16810731928126188
# 4795507292.819452
# 0.16793921195494477
# 4795526517.881439
# 0.16777127275418025
# 4795545723.718363
# 0.16760350146796554
# 4795564910.349449
# 0.16743589797260938
# 4795584077.793905
# 0.16726846206438495
# 4795603226.070915
# 0.16710119360504905
# 4795622355.19965
# 0.16693409241270274
# 4795641465.199255
# 0.16676715831272304
# 4795660556.088861
# 0.16660039115231484
# 4795679627.887577
# 0.16643379075685516
# 4795698680.614493
# 0.16626735697354889
# 4795717714.288684
# 0.16610108962049708
# 4795736728.9292
# 0.16593498852307675
# 4795755724.555076
# ...

# %%
print(sol42.pi)
# Out:
# 743760027, -120.06421177459468, -120.0707661115891, -120.07732044858349, -120.08387478557792, -120.09042912257232, -120.09698345956672, -120.10353779656113, -120.11009213355553, -120.11664647054995, -120.12320080754435, -120.12975514453876, -120.13630948153316, -120.14286381852757, -120.14941815552197, -120.15597249251638, -120.1625268295108, -120.1690811665052, -120.1756355034996, -120.18218984049402, -120.18874417748842, -120.19529851448283, -120.20185285147724, -120.20840718847164, -120.21496152546605, -120.22151586246046, -120.22807019945486, -120.23462453644927, -120.24117887344369, -120.24773321043808, -120.2542875474325, -120.26084188442691, -120.26739622142132, -120.27395055841572, -120.28050489541013, -120.28705923240453, -120.29361356939894, -120.30016790639334, -120.30672224338775, -120.31327658038217, -120.31983091737656, -120.32638525437098, -120.33293959136539, -120.3394939283598, -120.3460482653542, -120.3526026023486, -120.35915693934301, -120.36571127633741, -120.372
# ...

# %%
disc=ex6.discount(par41)
print((np.sum(disc.disc*sim41.pi)-np.sum(disc.disc*sim45.pi))/np.sum(disc.disc*sim41.pi))

print((np.sum(disc.disc*sim42.pi)-np.sum(disc.disc*sim46.pi))/np.sum(disc.disc*sim42.pi))

print((np.sum(disc.disc*sim41.util)-np.sum(disc.disc*sim45.util))/np.sum(disc.disc*sim41.util))

print((np.sum(disc.disc*sim42.util)-np.sum(disc.disc*sim46.util))/np.sum(disc.disc*sim42.util))

print(np.sum(disc.disc*(sim45.pi-sim41.pi))+np.sum(disc.disc*(sim45.util-sim41.util))-np.sum(par42.W*par42.G*sim45.lo*disc.disc))

print(np.sum(disc.disc*(sim46.pi-sim42.pi))+np.sum(disc.disc*(sim46.util-sim42.util))-np.sum(par42.W*par42.G*sim46.lo*disc.disc))
# Out:
# -0.09703654997870145
# -0.19229998448025173
# -0.20106122694839487
# -0.016094133796136938
# 1034.6304296603653
# 528.0665524144931

# %%
par42.simN=720
par42.M_ini=1500
par42.I_ini=0.01
sim45 = ex6.simu(par42, sol42)
sim46 = ex6.simu_wl(par42, sol42)
sim47 = ex6.simu_sl(par42, sol42)
sim48 = ex6.simu_swl(par42, sol42)
# Out:
# 4
# 4
# 4
# 4
# 4
# 4
# 1288.8163755857545
# 1
# 1290.1514814297561
# 1
# 1291.4436611604294
# 1
# 1292.6940520137057
# 1
# 1293.9037603915785
# 1
# 1295.0738628044035
# 1
# 1296.2054067814868
# 1
# 1297.2994117510132
# 1
# 1298.3568698903275
# 1
# 1299.378746947559
# 1
# 1300.3659830355516
# 1
# 1301.319493399031
# 1
# 1302.2401691559176
# 1
# 1303.1288780136622
# 1
# 1303.986464961463
# 1
# 1304.813752939189
# 1
# 1305.6115434838125
# 1
# 1306.3806173541348
# 1
# 1307.1217351345551
# 1
# 1307.8356378186174
# 1
# 1308.5230473730417
# 1
# 1309.1846672829276
# 1
# 1309.821183078796
# 1
# 1310.4332628461061
# 1
# 1311.021557717878
# 1
# 1311.5867023510157
# 1
# 1312.1293153869149
# 1
# 1312.6499998969202
# 1
# 1313.1493438131713
# 1
# 1313.627920345366
# 1
# 1314.086288383946
# 1
# 1314.5249928901987
# 1
# 1314.9445652737415
# 1
# 1315.3455237578514
# 1
# 1315.7283737330777
# 1
# 1316.0936080995632
# 1
# 1316.4417075984832
# 1
# 1316.7731411329983
# 1
# 1317.0883660791017
# 1
# ...

# %%
fig = plt.figure(figsize=(15,8))# figsize is in inches...

ax_right = fig.add_subplot(4,3,1)
ax_right.plot(sim45.grid, sim45.I, label='Baseline with wage-compensation')
ax_right.plot(sim45.grid, sim46.I, label='Firm-sector lockdown')
ax_right.plot(sim45.grid, sim47.I, label='Social-lockdown')
#ax_right.plot(sim45.grid, sim44.I, label='Firm and Social-lockdown')
ax_right.set_xlabel(f"$Day$")
ax_right.set_ylabel(f"$Infected (I_t)$")
leg = ax_right.legend()

ax_right = fig.add_subplot(4,3,2)
ax_right.plot(sim45.grid, sim45.lw)
ax_right.plot(sim45.grid, sim46.lw)
ax_right.plot(sim45.grid, sim47.lw)
#ax_right.plot(sim45.grid, sim44.lw)
ax_right.set_xlabel(f"$Days$")
ax_right.set_ylabel(r"$Labor usage L_{wt}$")

ax_right = fig.add_subplot(4,3,3)
ax_right.plot(sim45.grid, sim45.l)
ax_right.plot(sim45.grid, sim46.l)
ax_right.plot(sim45.grid, sim47.l)
#ax_right.plot(sim45.grid, sim44.l)
ax_right.set_xlabel(f"$Days$")
ax_right.set_ylabel(f"$Activity (l_t)$")

ax_right = fig.add_subplot(4,3,4)
ax_right.plot(sim45.grid, sim45.K)
ax_right.plot(sim45.grid, sim46.K)
ax_right.plot(sim45.grid, sim47.K)
ax_right.set_xlabel(f"$Days$")
ax_right.set_ylabel(f"$Capitalusage (K_t)$")

ax_right = fig.add_subplot(4,3,5)
ax_right.plot(sim45.grid, sim45.M)
ax_right.plot(sim45.grid, sim46.M)
ax_right.plot(sim45.grid, sim47.M)
#ax_right.plot(sim45.grid, sim44.M)
ax_right.set_xlabel(f"$Days$")
ax_right.set_ylabel(f"$Funds (M_t)$")

ax_right = fig.add_subplot(4,3,6)
ax_right.plot(sim45.grid, sim45.Y)
ax_right.plot(sim45.grid, sim46.Y)
ax_right.plot(sim45.grid, sim47.Y)
##3ax_right.plot(sim45.grid, sim44.Y)
ax_right.set_xlabel(f"$Days$")
ax_right.set_ylabel(f"$Production (Y_t)$")

ax_right = fig.add_subplot(4,3,7)
ax_right.plot(sim45.grid, sim45.c)
ax_right.plot(sim45.grid, sim46.c)
ax_right.plot(sim45.grid, sim47.c)
#ax_right.plot(sim45.grid, sim44.c)
ax_right.set_xlabel(f"$Day$")
ax_right.set_ylabel(f"$Spending on alternative good(c_t)$")

ax_right = fig.add_subplot(4,3,8)
ax_right.plot(sim45.grid, sim45.R)
ax_right.plot(sim45.grid, sim46.R)
ax_right.plot(sim45.grid, sim47.R)
##ax_right.plot(sim45.grid, sim44.R)
ax_right.set_xlabel(f"$Day$")
ax_right.set_ylabel(f"$Recovered (R_t)$")

ax_right = fig.add_subplot(4,3,9)
ax_right.plot(sim45.grid, sim45.p)
ax_right.plot(sim45.grid, sim46.p)
ax_right.plot(sim45.grid, sim47.p)
##ax_right.plot(sim45.grid, sim44.p)
ax_right.set_xlabel(f"$Day$")
ax_right.set_ylabel(f"$Price (p_t)$")

ax_right = fig.add_subplot(4,3,10)
ax_right.plot(sim45.grid, sim45.Q)
ax_right.plot(sim45.grid, sim46.Q)
ax_right.plot(sim45.grid, sim47.Q)
#ax_right.plot(sim45.grid, sim44.Q)
ax_right.set_xlabel(f"$Day$")
ax_right.set_ylabel(f"$Quarantined (Q_t)$")

ax_right = fig.add_subplot(4,3,11)
ax_right.plot(sim45.grid, sim45.pi)
ax_right.plot(sim45.grid, sim46.pi)
ax_right.plot(sim45.grid, sim47.pi)
#ax_right.plot(sim45.grid, sim44.pi)
ax_right.set_xlabel(f"$Day$")
ax_right.set_ylabel(r"$Profits (\Pi_t)$")

ax_right = fig.add_subplot(4,3,12)
ax_right.plot(sim45.grid, sim45.util)
ax_right.plot(sim45.grid, sim46.util)
ax_right.plot(sim45.grid, sim47.util)
#ax_right.plot(sim45.grid, sim44.Pos)
ax_right.set_xlabel(f"$Day$")
ax_right.set_ylabel(r"$Utility (U_t) $")

fig.savefig('lockdownswithGAlt.png')

# %%
#One time cash injection
par41.cash=1
sim49 = ex6.simu(par41, sol41)
# Out:
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 1247.2078687673077
# 1
# 1248.5486143299543
# 1
# 1249.8490248796456
# 1
# 1251.110311719302
# 1
# 1252.3336497509338
# 1
# 1253.5201785713225
# 1
# 1254.6710035346864
# 1
# 1255.787196783322
# 1
# 1256.869798247187
# 1
# 1257.9198166133574
# 1
# 1258.9382302662705
# 1
# 1259.925988199627
# 1
# 1260.8840109008129
# 1
# 1261.8131912086628
# 1
# 1262.7143951453731
# 1
# 1263.588462723339
# 1
# 1264.4362087276756
# 1
# 1265.2584234751532
# 1
# 1266.0558735502586
# 1
# 1266.8293025190724
# 1
# 1267.57943162163
# 1
# 1268.3069604434177
# 1
# 1269.0125675666281
# 1
# 1269.6969112017928
# 1
# 1270.3606298003758
# 1
# 1271.0043426489092
# 1
# 1271.6286504452225
# 1
# 1272.2341358573108
# 1
# 1272.82136406536
# 1
# 1273.3908832874433
# 1
# 1273.9432252893755
# 1
# 1274.4789058792085
# 1
# 1274.9984253868286
# 1
# 1275.5022691291053
# 1
# 1275.9909078610294
# 1
# 1276.4647982132599
# 1
# 1276.9243831164938
# 1
# 1277.3700922130547
# 1
# ...

# %%
fig = plt.figure(figsize=(15,8))# figsize is in inches...

ax_right = fig.add_subplot(4,3,1)
ax_right.plot(sim41.grid, sim41.I, label='Baseline')
ax_right.plot(sim41.grid, sim49.I, label='Cash injection')
ax_right.set_xlabel(f"$Day$")
ax_right.set_ylabel(f"$Infected (I_t)$")
leg = ax_right.legend()

ax_right = fig.add_subplot(4,3,2)
ax_right.plot(sim41.grid, sim41.lw)
ax_right.plot(sim41.grid, sim49.lw)
ax_right.set_xlabel(f"$Days$")
ax_right.set_ylabel(r"$Labor usage (L_{wt})$")

ax_right = fig.add_subplot(4,3,3)
ax_right.plot(sim41.grid, sim41.l)
ax_right.plot(sim41.grid, sim49.l)
ax_right.set_xlabel(f"$Days$")
ax_right.set_ylabel(f"$Activity (l_t)$")

ax_right = fig.add_subplot(4,3,4)
ax_right.plot(sim41.grid, sim41.K)
ax_right.plot(sim41.grid, sim49.K)
ax_right.set_xlabel(f"$Days$")
ax_right.set_ylabel(f"$Capitalusage(K_t)$")

ax_right = fig.add_subplot(4,3,5)
ax_right.plot(sim41.grid, sim41.M)
ax_right.plot(sim41.grid, sim49.M)
ax_right.set_xlabel(f"$Days$")
ax_right.set_ylabel(f"$Funds (M_t)$")

ax_right = fig.add_subplot(4,3,6)
ax_right.plot(sim41.grid, sim41.Y)
ax_right.plot(sim41.grid, sim49.Y)
ax_right.set_xlabel(f"$Days$")
ax_right.set_ylabel(f"$Production (Y_t)$")

ax_right = fig.add_subplot(4,3,7)
ax_right.plot(sim41.grid, sim41.c)
ax_right.plot(sim41.grid, sim49.c)
ax_right.set_xlabel(f"$Day$")
ax_right.set_ylabel(f"$Spending on alternative good(c_t)$")

ax_right = fig.add_subplot(4,3,8)
ax_right.plot(sim41.grid, sim41.R)
ax_right.plot(sim41.grid, sim49.R)
ax_right.set_xlabel(f"$Day$")
ax_right.set_ylabel(f"$Recovered (R_t)$")

ax_right = fig.add_subplot(4,3,9)
ax_right.plot(sim41.grid, sim41.p)
ax_right.plot(sim41.grid, sim49.p)
ax_right.set_xlabel(f"$Day$")
ax_right.set_ylabel(f"$Price (p_t)$")

ax_right = fig.add_subplot(4,3,10)
ax_right.plot(sim41.grid, sim41.Q)
ax_right.plot(sim41.grid, sim49.Q)
ax_right.set_xlabel(f"$Day$")
ax_right.set_ylabel(f"$Quarantined (Q_t)$")

ax_right = fig.add_subplot(4,3,11)
ax_right.plot(sim41.grid, sim41.pi)
ax_right.plot(sim41.grid, sim49.pi)
ax_right.set_xlabel(f"$Day$")
ax_right.set_ylabel(r"$Profits (\Pi_t)$")

ax_right = fig.add_subplot(4,3,12)
ax_right.plot(sim41.grid, sim41.util)
ax_right.plot(sim41.grid, sim49.util)
ax_right.set_xlabel(f"$Day$")
ax_right.set_ylabel(f"$Utility (U_t)$")

fig.savefig('Cashinject.png')

# %%
print((np.sum(disc.disc*sim49.pi)-np.sum(disc.disc*sim41.pi))/np.sum(disc.disc*sim41.pi))

print((np.sum(disc.disc*sim49.util)-np.sum(disc.disc*sim41.util))/np.sum(disc.disc*sim41.util))

print(np.sum(disc.disc*sim49.util)-np.sum(disc.disc*sim41.util)+np.sum(disc.disc*sim49.pi)-np.sum(disc.disc*sim41.pi))
print(par41.beta**120*1000)
# Out:
# 0.036115680975210965
# 0.0020988070775634898
# 451.45125323811953
# 886.8671875860638

# %%
print(par42.H)
print(par41.H)
# Out:
# 0.65
# 0.65

# %%
print(sol41.Y)
# Out:
# []
