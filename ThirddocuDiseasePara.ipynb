# %%
# magics: ensures that any changes to the modules loaded below will be re-loaded automatically
# %reload_ext autoreload
# %autoreload 3

# load general packages
import numpy as np
import matplotlib.pyplot as plt
plt.style.use('seaborn-whitegrid')
from mpl_toolkits.mplot3d import Axes3D
# load modules related to this exercise
import tools_Exercise_1_6 as tools
import Coronamacromodeldeathandreinfectionsycopyco as ex6
import Coronamacromodeldeathandreinfectionsycopyco as ex7
import Coronamacromodeldeathandreinfectionsycopyco as ex8

# %%
# Solving models for different disease parameters. Setting up all
import Coronamacromodeldeathandreinfectionsycopyco as ex9

# %%
par31 = ex7.setup()
sol31 = ex6.solve_cons_inf(par31)
sim31=ex7.simu(par31, sol31)
par31.sigma=0.05
sol32 = ex6.solve_cons_inf(par31)
sim32=ex7.simu(par31, sol32)
par31.sigma=0.005
sol33 = ex6.solve_cons_inf(par31)
sim33=ex7.simu(par31, sol33)
# Out:
# 499003
# 2188833295.982789
# 25.88238549410744
# 2194230013.875177
# 25.856493862700518
# 2199621337.3955526
# 25.83062813482684
# 2205007271.8402925
# 25.804788284574897
# 2210387822.5031557
# 25.77897428603501
# 2215762994.6752157
# 25.753186113357515
# 2221132793.644789
# 25.727423740696395
# 2226497224.6976213
# 25.701687142234732
# 2231856293.1163034
# 25.675976292177438
# 2237210004.1804786
# 25.650291164767623
# 2242558363.1667933
# 25.624631734273862
# 2247901375.348839
# 25.59899797497019
# 2253239045.997098
# 25.57338986117429
# 2258571380.3788843
# 25.547807367231144
# 2263898383.7582965
# 25.52225046750391
# 2269220061.396165
# 25.49671913637576
# 2274536418.5499973
# 25.471213348273523
# 2279847460.4739375
# 25.44573307763676
# 2285153192.418717
# 25.42027829892686
# 2290453619.631604
# 25.39484898664159
# 2295748747.3563657
# 25.36944511529873
# 2301038580.8332205
# 25.3440666594488
# 2306323125.2987986
# 25.318713593645953
# 2311602385.9861
# 25.293385892500737
# ...

# %%
#Solving for change in Sigma and baseline¨
par31 = ex7.setup()
par31.nd=par31.nd*2
par31.d=par31.d*2
par31.Z=par31.Z*2
sol34 = ex6.solve_cons_inf(par31)
sim34=ex6.simu(par31, sol34)
par31 = ex7.setup()
par31.nd=par31.nd*10
par31.d=par31.d*10
par31.Z=par31.Z*10
sol35 = ex6.solve_cons_inf(par31)
sim35=ex6.simu(par31, sol35)
# Out:
# 25150356098311
# 0.7217924392898567
# 0.7210705656762002
# 0.7203494140412658
# 0.7196289836574579
# 0.7189092738408362
# 0.7181902838128735
# 0.7174720128750778
# 0.7167544602998532
# 0.7160376254105358
# 0.715321507457702
# 0.7146061056992039
# 0.7138914194802055
# 0.7131774480149033
# 0.7124641906484612
# 0.7117516466387315
# 0.7110398152581183
# 0.7103286958445096
# 0.7096182876266539
# 0.7089085899206111
# 0.7081996020278893
# 0.7074913232208928
# 0.7067837527865777
# 0.7060768900410039
# 0.7053707342492999
# 0.7046652847056976
# 0.7039605407189811
# 0.7032565015688306
# 0.702553166578582
# 0.7018505350279156
# 0.7011486061892356
# 0.7004473793931538
# 0.6997468539120746
# 0.6990470290838857
# 0.6983479041446117
# 0.6976494784539682
# 0.6969517512770835
# 0.6962547219445696
# 0.6955583897215547
# 0.6948627539240988
# 0.6941678138900897
# 0.6934735688773799
# 0.6927800182020292
# 0.6920871612164774
# 0.691394997156749
# 0.6907035253534559
# 0.69001274513721
# 0.6893226557949674
# ...

# %%
par31 = ex7.setup()
par31.phi1 = par31.phi1*0.5
par31.phi2 = par31.phi3*0.5
par31.phi3 = par31.phi3*0.5
#sol36 = ex6.solve_cons_inf(par31)
sim36=ex9.simu(par31, sol36)
par31 = ex7.setup()
par31.phi1 = par31.phi1*2
par31.phi2 = par31.phi3*2
par31.phi3 = par31.phi3*2
#sol37 = ex6.solve_cons_inf(par31)
sim37=ex9.simu(par31, sol37)
# Out:
# 01202730738161
# 0.8605986691812232
# 0.8610750985954766
# 0.8615495694406227
# 0.8620220898109731
# 0.8624926677711152
# 0.8629613113559279
# 0.8634280285705968
# 0.8638928273906333
# 0.864355715761897
# 0.8648167016006179
# 0.8652757927934254
# 0.8657329971973744
# 0.8661883226399778
# 0.866641776919237
# 0.86709336780368
# 0.8675431030323942
# 0.8679909903150703
# 0.8684370373320378
# 0.8688812517343113
# 0.8693236411436329
# 0.8697642131525197
# 0.8702029753243082
# 0.8706399351932093
# 0.8710751002643526
# 0.8715084780138443
# 0.8719400758888165
# 0.8723699013074867
# 0.8727979616592105
# 0.8732239330316578
# 0.8736480164951091
# 0.8740703635075847
# 0.8744909812563925
# 0.8749098769013435
# 0.8753270575748157
# 0.8757425303818183
# 0.8761563024000582
# 0.8765683806800013
# 0.8769787722449388
# 0.8773874840910496
# 0.8777945231874646
# 0.8781998964763299
# 0.8786036108728713
# 0.8790056732654594
# 0.8794060905156716
# 0.8798048694583596
# 0.8802020169017123
# 0.8805975396273223
# ...

# %%
#Running for change in lethaliity

# %%
# Out:
# 0.005

# %%
#Running for change in infectivity

# %%
#Running sims

# %%
#Plotting first
fig1 = plt.figure(figsize=(15,8))
ax_right = fig1.add_subplot(4,3,1)
ax_right.plot(sim31.grid, sim32.I, label='sigma = 0.05')
ax_right.plot(sim31.grid, sim33.I, label='sigma = 0.005 ')
ax_right.plot(sim31.grid, sim31.I, label='sigma = 0.001')
ax_right.set_xlabel(f"$Day$")
ax_right.set_ylabel(r"$Infected (I_t)$")
leg = ax_right.legend()

ax = fig1.add_subplot(4,3,2)
ax.plot(sim31.grid, sim32.lw)
ax.plot(sim31.grid, sim33.lw)
ax.plot(sim31.grid, sim31.lw)
ax.set_xlabel(f"$Days$")
ax.set_ylabel(r"$Labour(L_{wt})$")

ax = fig1.add_subplot(4,3,3)
ax.plot(sim31.grid, sim32.l)
ax.plot(sim31.grid, sim33.l)
ax.plot(sim31.grid, sim31.l)
ax.set_xlabel(f"$Days$")
ax.set_ylabel(f"$Activity(l_t)$")

ax = fig1.add_subplot(4,3,4)
ax.plot(sim31.grid, sim32.pi)
ax.plot(sim31.grid, sim33.pi)
ax.plot(sim31.grid, sim31.pi)
ax.set_xlabel(f"$Days$")
ax.set_ylabel(r"$Profit (\Pi_t)$")

ax = fig1.add_subplot(4,3,5)
ax.plot(sim31.grid, sim32.util)
ax.plot(sim31.grid, sim33.util)
ax.plot(sim31.grid, sim31.util)
ax.set_xlabel(f"$Days$")
ax.set_ylabel(f"$Utilily (U_t)$")

ax = fig1.add_subplot(4,3,6)
ax.plot(sim31.grid, sim32.Y)
ax.plot(sim31.grid, sim33.Y)
ax.plot(sim31.grid, sim31.Y)
ax.set_xlabel(f"$Days$")
ax.set_ylabel(f"$Production(Y_t)$")

ax = fig1.add_subplot(4,3,7)
ax.plot(sim31.grid, sim32.gamma2)
ax.plot(sim31.grid, sim33.gamma2)
ax.plot(sim31.grid, sim31.gamma2)
ax.set_xlabel(f"$Day$")
ax.set_ylabel(f"$Prob\ of\ detection (\u03B3_2)$")

ax = fig1.add_subplot(4,3,8)
ax.plot(sim31.grid, sim32.R)
ax.plot(sim31.grid, sim33.R)
ax.plot(sim31.grid, sim31.R)
ax.set_xlabel(f"$Day$")
ax.set_ylabel(f"$Recovered(R_t)$")

ax = fig1.add_subplot(4,3,9)
ax.plot(sim31.grid, sim32.p)
ax.plot(sim31.grid, sim33.p)
ax.plot(sim31.grid, sim31.p)
ax.set_xlabel(f"$Day$")
ax.set_ylabel(f"$Price(p_t)$")

ax = fig1.add_subplot(4,3,10)
ax.plot(sim31.grid, sim32.Q)
ax.plot(sim31.grid, sim33.Q)
ax.plot(sim31.grid, sim31.Q)
ax.set_xlabel(f"$Day$")
ax.set_ylabel(f"$Quarantined(Q_t)$")

ax = fig1.add_subplot(4,3,11)
ax.plot(sim31.grid, sim32.D)
ax.plot(sim31.grid, sim33.D)
ax.plot(sim31.grid, sim31.D)
ax.set_xlabel(f"$Day$")
ax.set_ylabel(r"$Deaths (D_t)$")

ax = fig1.add_subplot(4,3,12)
ax.plot(sim31.grid, sim32.Pos)
ax.plot(sim31.grid, sim33.Pos)
ax.plot(sim31.grid, sim31.Pos)
ax.set_xlabel(f"$Day$")
ax.set_ylabel(r"$Test\ Pos\ Rate (\frac{\gamma_2 I_t}{Tests})$")

fig1.savefig('Changingsigma.png')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-b37f29151377> in <module>
#       2 fig1 = plt.figure(figsize=(15,8))
#       3 ax_right = fig1.add_subplot(4,3,1)
# ----> 4 ax_right.plot(sim31.grid, sim32.I, label='sigma = 0.05')
#       5 ax_right.plot(sim31.grid, sim31.I, label='sigma = 0.003')
#       6 ax_right.plot(sim31.grid, sim33.I, label='sigma = 0.1 ')
#
# NameError: name 'sim31' is not defined

# %%
#Plotting second
fig1 = plt.figure(figsize=(15,8))

ax_right = fig1.add_subplot(4,3,1)
ax_right.plot(sim31.grid, sim34.I, label='Double lethality')
ax_right.plot(sim31.grid, sim31.I, label='Baseline')
ax_right.plot(sim31.grid, sim35.I, label='10x lethality')
ax_right.set_xlabel(f"$Day$")
ax_right.set_ylabel(r"$Infected(I_t)$")
leg = ax_right.legend()


ax = fig1.add_subplot(4,3,2)
ax.plot(sim31.grid, sim34.lw)
ax.plot(sim31.grid, sim31.lw)
ax.plot(sim31.grid, sim35.lw)
ax.set_xlabel(f"$Days$")
ax.set_ylabel(r"$Labour(L_{wt})$")

ax = fig1.add_subplot(4,3,3)
ax.plot(sim31.grid, sim34.l)
ax.plot(sim31.grid, sim31.l)
ax.plot(sim31.grid, sim35.l)
ax.set_xlabel(f"$Days$")
ax.set_ylabel(f"$Activity(l_t)$")

ax = fig1.add_subplot(4,3,4)
ax.plot(sim31.grid, sim34.pi)
ax.plot(sim31.grid, sim31.pi)
ax.plot(sim31.grid, sim35.pi)
ax.set_xlabel(f"$Days$")
ax.set_ylabel(r"$Profit (\Pi_t)$")

ax = fig1.add_subplot(4,3,5)
ax.plot(sim31.grid, sim34.util)
ax.plot(sim31.grid, sim31.util)
ax.plot(sim31.grid, sim35.util)
ax.set_xlabel(f"$Days$")
ax.set_ylabel(f"$Utilily (U_t)$")

ax = fig1.add_subplot(4,3,6)
ax.plot(sim31.grid, sim34.Y)
ax.plot(sim31.grid, sim31.Y)
ax.plot(sim31.grid, sim35.Y)
ax.set_xlabel(f"$Days$")
ax.set_ylabel(f"$Production(Y_t)$")

ax = fig1.add_subplot(4,3,7)
ax.plot(sim31.grid, sim34.gamma2)
ax.plot(sim31.grid, sim31.gamma2)
ax.plot(sim31.grid, sim35.gamma2)
ax.set_xlabel(f"$Day$")
ax.set_ylabel(f"$Prob\ of\ detection (\u03B3_2)$")

ax = fig1.add_subplot(4,3,8)
ax.plot(sim31.grid, sim34.R)
ax.plot(sim31.grid, sim31.R)
ax.plot(sim31.grid, sim35.R)
ax.set_xlabel(f"$Day$")
ax.set_ylabel(f"$Recovered(R_t)$")

ax = fig1.add_subplot(4,3,9)
ax.plot(sim31.grid, sim34.p)
ax.plot(sim31.grid, sim31.p)
ax.plot(sim31.grid, sim35.p)
ax.set_xlabel(f"$Day$")
ax.set_ylabel(f"$Price(p_t)$")

ax = fig1.add_subplot(4,3,10)
ax.plot(sim31.grid, sim34.Q)
ax.plot(sim31.grid, sim31.Q)
ax.plot(sim31.grid, sim35.Q)
ax.set_xlabel(f"$Day$")
ax.set_ylabel(f"$Quarantined(Q_t)$")

ax = fig1.add_subplot(4,3,11)
ax.plot(sim31.grid, sim34.D)
ax.plot(sim31.grid, sim31.D)
ax.plot(sim31.grid, sim35.D)
ax.set_xlabel(f"$Day$")
ax.set_ylabel(r"$Deaths (D_t)$")

ax = fig1.add_subplot(4,3,12)
ax.plot(sim31.grid, sim34.Pos)
ax.plot(sim31.grid, sim31.Pos)
ax.plot(sim31.grid, sim35.Pos)
ax.set_xlabel(f"$Day$")
ax.set_ylabel(r"$Test\ Pos\ Rate (\frac{\gamma_2 I_t}{Tests})$")

fig1.savefig('Changinglethal.png')

# %%
#Plotting third
fig1 = plt.figure(figsize=(15,8))

ax_right = fig1.add_subplot(4,3,1)
ax_right.plot(sim31.grid, sim36.I, label='Half infectivity')
ax_right.plot(sim31.grid, sim31.I, label='Baseline')
ax_right.plot(sim31.grid, sim37.I, label='Double Infectivity')
ax_right.set_xlabel(f"$Day$")
ax_right.set_ylabel(r"$Infected(I_t)$")
leg = ax_right.legend()


ax = fig1.add_subplot(4,3,2)
ax.plot(sim31.grid, sim36.lw)
ax.plot(sim31.grid, sim31.lw)
ax.plot(sim31.grid, sim37.lw)
ax.set_xlabel(f"$Days$")
ax.set_ylabel(r"$Labour(L_{wt})$")

ax = fig1.add_subplot(4,3,3)
ax.plot(sim31.grid, sim36.l)
ax.plot(sim31.grid, sim31.l)
ax.plot(sim31.grid, sim37.l)
ax.set_xlabel(f"$Days$")
ax.set_ylabel(f"$Activity(l_t)$")

ax = fig1.add_subplot(4,3,4)
ax.plot(sim31.grid, sim36.pi)
ax.plot(sim31.grid, sim31.pi)
ax.plot(sim31.grid, sim37.pi)
ax.set_xlabel(f"$Days$")
ax.set_ylabel(r"$Profit (\Pi_t)$")

ax = fig1.add_subplot(4,3,5)
ax.plot(sim31.grid, sim36.util)
ax.plot(sim31.grid, sim31.util)
ax.plot(sim31.grid, sim37.util)
ax.set_xlabel(f"$Days$")
ax.set_ylabel(f"$Utilily (U_t)$")

ax = fig1.add_subplot(4,3,6)
ax.plot(sim31.grid, sim36.Y)
ax.plot(sim31.grid, sim31.Y)
ax.plot(sim31.grid, sim37.Y)
ax.set_xlabel(f"$Days$")
ax.set_ylabel(f"$Production(Y_t)$")

ax = fig1.add_subplot(4,3,7)
ax.plot(sim31.grid, sim36.gamma2)
ax.plot(sim31.grid, sim31.gamma2)
ax.plot(sim31.grid, sim37.gamma2)
ax.set_xlabel(f"$Day$")
ax.set_ylabel(f"$Prob\ of\ detection (\u03B3_2)$")

ax = fig1.add_subplot(4,3,8)
ax.plot(sim31.grid, sim36.R)
ax.plot(sim31.grid, sim31.R)
ax.plot(sim31.grid, sim37.R)
ax.set_xlabel(f"$Day$")
ax.set_ylabel(f"$Recovered(R_t)$")

ax = fig1.add_subplot(4,3,9)
ax.plot(sim31.grid, sim36.p)
ax.plot(sim31.grid, sim31.p)
ax.plot(sim31.grid, sim37.p)
ax.set_xlabel(f"$Day$")
ax.set_ylabel(f"$Price(p_t)$")

ax = fig1.add_subplot(4,3,10)
ax.plot(sim31.grid, sim36.Q)
ax.plot(sim31.grid, sim31.Q)
ax.plot(sim31.grid, sim37.Q)
ax.set_xlabel(f"$Day$")
ax.set_ylabel(f"$Quarantined(Q_t)$")

ax = fig1.add_subplot(4,3,11)
ax.plot(sim31.grid, sim36.D)
ax.plot(sim31.grid, sim31.D)
ax.plot(sim31.grid, sim37.D)
ax.set_xlabel(f"$Day$")
ax.set_ylabel(r"$Deaths (D_t)$")

ax = fig1.add_subplot(4,3,12)
ax.plot(sim31.grid, sim36.Pos)
ax.plot(sim31.grid, sim31.Pos)
ax.plot(sim31.grid, sim37.Pos)
ax.set_xlabel(f"$Day$")
ax.set_ylabel(r"$Test\ Pos\ Rate (\frac{\gamma_2 I_t}{Tests})$")

fig1.savefig('changinginfectivity.png')

# %%
#Results for misjudging

par31 = ex7.setup()
par31.phi1 = par31.phi1*1.05
par31.phi2 = par31.phi2*1.05
par31.phi3 = par31.phi3*1.05
sim38=ex9.simu(par31, sol31)
par31 = ex7.setup()
par31.phi1 = par31.phi1*0.95
par31.phi2 = par31.phi2*0.95
par31.phi3 = par31.phi3*0.95
sim39=ex9.simu(par31, sol32)
par31 = ex7.setup()
par31.sigma=par31.sigma*1.05
par31.t=par31.t*1.05
sim310 = ex9.simu(par31, sol31)
par31 = ex7.setup()
par31.sigma=par31.sigma*0.95
par31.t=par31.t*0.95
sim311 = ex9.simu(par31, sol31)
par31 = ex7.setup()
sim312 = ex9.simu(par31, sol31)
# Out:
# .6494430176066947
# 0.6499228947828721
# 0.6504013700653345
# 0.6508784501850808
# 0.6513541418403056
# 0.6518284516964165
# 0.6523013863860606
# 0.6527729525091603
# 0.6532431566329595
# 0.6537120052920727
# 0.6541795049885466
# 0.6546456621919268
# 0.6551104833393294
# 0.6555739748355219
# 0.6560361430530052
# 0.6564969943321066
# 0.6569565349810722
# 0.6574147712761673
# 0.6578717094617803
# 0.6583273557505293
# 0.6587817163233731
# 0.6592347973297276
# 0.6596866048875818
# 0.6601371450836188
# 0.6605864239733393
# 0.6610358618389958
# 0.6614879639017162
# 0.661938669182616
# 0.6623879943132667
# 0.6628359552030064
# 0.6632825670822725
# 0.6637278445433376
# 0.6641718015785878
# 0.6646144516164977
# 0.6650558075554263
# 0.6654958817953609
# 0.6659346862677398
# 0.6663722324634483
# 0.6668085314591141
# 0.6672435939417878
# 0.6676774302321128
# 0.6681100503060717
# 0.6685414638153926
# 0.6689716801066957
# 0.66940070823946
# 0.6698285570028732
# 0.6702552349316403
# ...

# %%
par31 = ex7.setup()
simu312 = ex9.simu(par31, sol31)
# Out:
# 1.0
# 0.4878884178814831
# 0.48326120417952156
# 0.4788951009727287
# 0.47477865348767045
# 0.4709009283482737
# 0.4672514831699215
# 0.4638203394502394
# 0.4605979581206567
# 0.4575752172734593
# 0.45474339169171163
# 0.4520941338942676
# 0.4496194564723064
# 0.4473117155425858
# 0.4451635951797536
# 0.44316809271838037
# 0.44131850483704205
# 0.4396084143533544
# 0.4380316776715668
# 0.4365824128340979
# 0.43525498813590124
# 0.4340440112663694
# 0.43294431894799407
# 0.4319509670445206
# 0.4310592211141185
# 0.43026454738529357
# 0.429562604135053
# 0.42894923345029434
# 0.42842045335461093
# 0.42797245028373465
# 0.42760157189374287
# 0.42730432018695136
# 0.4270773449411237
# 0.4269174374283015
# 0.42682152441015064
# 0.42678666239731455
# 0.42681003216079555
# 0.4268889334839145
# 0.4270207801438915
# 0.42720309511258636
# 0.4274335059663771
# 0.4277097404956276
# 0.4280296225046069
# 0.42839106779315095
# 0.42879208031175087
# 0.42923074848214327
# 0.42970524167584695
# ...

# %%
fig1 = plt.figure(figsize=(15,8))# figsize is in inches...

ax = fig1.add_subplot(4,3,1)
ax.plot(simu312.grid, sim38.I, label='Infectivity 5 percent higher higher than belief')
ax.plot(simu312.grid, simu312.I, label='Baseline')
ax.plot(simu312.grid, sim39.I, label='Infectivity 5 percent lower than belief')
ax.set_xlabel(f"$Day$")
ax.set_ylabel(r"$Infected(I_t)$")
leg = ax.legend()

ax = fig1.add_subplot(4,3,2)
ax.plot(simu312.grid, sim38.lw)
ax.plot(simu312.grid, simu312.lw)
ax.plot(simu312.grid, sim39.lw)
ax.set_xlabel(f"$Days$")
ax.set_ylabel(r"$Labour(L_{wt})$")

ax = fig1.add_subplot(4,3,3)
ax.plot(simu312.grid, sim38.l)
ax.plot(simu312.grid, simu312.l)
ax.plot(simu312.grid, sim39.l)
ax.set_xlabel(f"$Days$")
ax.set_ylabel(f"$Activity(l_t)$")

ax = fig1.add_subplot(4,3,4)
ax.plot(simu312.grid, sim38.pi)
ax.plot(simu312.grid, simu312.pi)
ax.plot(simu312.grid, sim39.pi)
ax.set_xlabel(f"$Days$")
ax.set_ylabel(r"$Profit (\Pi_t)$")

ax = fig1.add_subplot(4,3,5)
ax.plot(simu312.grid, sim38.util)
ax.plot(simu312.grid, simu312.util)
ax.plot(simu312.grid, sim39.util)
ax.set_xlabel(f"$Days$")
ax.set_ylabel(f"$Utilily (U_t)$")

ax = fig1.add_subplot(4,3,6)
ax.plot(simu312.grid, sim38.Y)
ax.plot(simu312.grid, simu312.Y)
ax.plot(simu312.grid, sim39.Y)
ax.set_xlabel(f"$Days$")
ax.set_ylabel(f"$Production(Y_t)$")

ax = fig1.add_subplot(4,3,7)
ax.plot(simu312.grid, sim38.gamma2)
ax.plot(simu312.grid, simu312.gamma2)
ax.plot(simu312.grid, sim39.gamma2)
ax.set_xlabel(f"$Day$")
ax.set_ylabel(f"$Prob\ of\ detection (\u03B3_2)$")

ax = fig1.add_subplot(4,3,8)
ax.plot(simu312.grid, sim38.R)
ax.plot(simu312.grid, simu312.R)
ax.plot(simu312.grid, sim39.R)
ax.set_xlabel(f"$Day$")
ax.set_ylabel(f"$Recovered(R_t)$")

ax = fig1.add_subplot(4,3,9)
ax.plot(simu312.grid, sim38.p)
ax.plot(simu312.grid, simu312.p)
ax.plot(simu312.grid, sim39.p)
ax.set_xlabel(f"$Day$")
ax.set_ylabel(f"$Price(p_t)$")

ax = fig1.add_subplot(4,3,10)
ax.plot(simu312.grid, sim38.Q)
ax.plot(simu312.grid, simu312.Q)
ax.plot(simu312.grid, sim39.Q)
ax.set_xlabel(f"$Day$")
ax.set_ylabel(f"$Quarantined(Q_t)$")

ax = fig1.add_subplot(4,3,11)
ax.plot(simu312.grid, sim38.D)
ax.plot(simu312.grid, simu312.D)
ax.plot(simu312.grid, sim39.D)
ax.set_xlabel(f"$Day$")
ax.set_ylabel(r"$Deaths (D_t)$")

ax = fig1.add_subplot(4,3,12)
ax.plot(simu312.grid, sim38.Pos)
ax.plot(simu312.grid, simu312.Pos)
ax.plot(simu312.grid, sim39.Pos)
ax.set_xlabel(f"$Day$")
ax.set_ylabel(r"$Test\ Pos\ Rate (\frac{\gamma_2 I_t}{Tests})$")

fig1.savefig('misjudgeinfec.png')

# %%
fig1 = plt.figure(figsize=(15,8))# figsize is in inches...

ax = fig1.add_subplot(4,3,1)
ax.plot(simu312.grid, sim38.I, label='Detection rate 5 percent higher higher than belief')
ax.plot(simu312.grid, sim31.I, label='Baseline')
ax.plot(simu312.grid, sim39.I, label='Detection rate 5 percent lower than belief')
ax.set_xlabel(f"$Day$")
ax.set_ylabel(r"$Infected(I_t)$")
leg = ax.legend()

ax = fig1.add_subplot(4,3,2)
ax.plot(sim31.grid, sim310.lw)
ax.plot(sim31.grid, sim31.lw)
ax.plot(sim31.grid, sim311.lw)
ax.set_xlabel(f"$Days$")
ax.set_ylabel(r"$Labour(L_{wt})$")

ax = fig1.add_subplot(4,3,3)
ax.plot(sim31.grid, sim310.l)
ax.plot(sim31.grid, sim31.l)
ax.plot(sim31.grid, sim311.l)
ax.set_xlabel(f"$Days$")
ax.set_ylabel(f"$Activity(l_t)$")

ax = fig1.add_subplot(4,3,4)
ax.plot(sim31.grid, sim310.pi)
ax.plot(sim31.grid, sim31.pi)
ax.plot(sim31.grid, sim311.pi)
ax.set_xlabel(f"$Days$")
ax.set_ylabel(r"$Profit (\Pi_t)$")

ax = fig1.add_subplot(4,3,5)
ax.plot(sim31.grid, sim310.util)
ax.plot(sim31.grid, sim31.util)
ax.plot(sim31.grid, sim311.util)
ax.set_xlabel(f"$Days$")
ax.set_ylabel(f"$Utilily (U_t)$")

ax = fig1.add_subplot(4,3,6)
ax.plot(sim31.grid, sim310.Y)
ax.plot(sim31.grid, sim31.Y)
ax.plot(sim31.grid, sim311.Y)
ax.set_xlabel(f"$Days$")
ax.set_ylabel(f"$Production(Y_t)$")

ax = fig1.add_subplot(4,3,7)
ax.plot(sim31.grid, sim310.gamma2)
ax.plot(sim31.grid, sim31.gamma2)
ax.plot(sim31.grid, sim311.gamma2)
ax.set_xlabel(f"$Day$")
ax.set_ylabel(f"$Prob\ of\ detection (\u03B3_2)$")

ax = fig1.add_subplot(4,3,8)
ax.plot(sim31.grid, sim310.R)
ax.plot(sim31.grid, sim31.R)
ax.plot(sim31.grid, sim311.R)
ax.set_xlabel(f"$Day$")
ax.set_ylabel(f"$Recovered(R_t)$")

ax = fig1.add_subplot(4,3,9)
ax.plot(sim31.grid, sim310.p)
ax.plot(sim31.grid, sim31.p)
ax.plot(sim31.grid, sim311.p)
ax.set_xlabel(f"$Day$")
ax.set_ylabel(f"$Price(p_t)$")

ax = fig1.add_subplot(4,3,10)
ax.plot(sim31.grid, sim310.Q)
ax.plot(sim31.grid, sim31.Q)
ax.plot(sim31.grid, sim311.Q)
ax.set_xlabel(f"$Day$")
ax.set_ylabel(f"$Quarantined(Q_t)$")

ax = fig1.add_subplot(4,3,11)
ax.plot(sim31.grid, sim310.D)
ax.plot(sim31.grid, sim31.D)
ax.plot(sim31.grid, sim311.D)
ax.set_xlabel(f"$Day$")
ax.set_ylabel(r"$Deaths(D_t))$")

ax = fig1.add_subplot(4,3,12)
ax.plot(sim31.grid, sim310.Pos)
ax.plot(sim31.grid, sim31.Pos)
ax.plot(sim31.grid, sim311.Pos)
ax.set_xlabel(f"$Day$")
ax.set_ylabel(r"$Test\ Pos\ Rate (\frac{\gamma_2 I_t}{Tests})$")

fig1.savefig('misjudgedarknum.png')

# %%
print(sim31.I)
# Out:
# [0.01       0.0107273  0.01148549 0.01227323 0.01308897 0.01393095
#  0.01479724 0.01568576 0.01659432 0.01752068 0.01846253 0.01941759
#  0.02038357 0.02132743 0.02216607 0.02283492 0.02349554 0.02416726
#  0.0248656  0.02549383 0.02605249 0.02655334 0.02700715 0.02740269
#  0.02774603 0.02804163 0.02829257 0.02850663 0.02871916 0.02893164
#  0.02914569 0.02936315 0.02958601 0.02981652 0.0300427  0.03024207
#  0.03041247 0.03054871 0.03064767 0.03071682 0.03076288 0.03079194
#  0.03080957 0.03082085 0.03083047 0.03084278 0.0308618  0.03089129
#  0.03093477 0.03099551 0.03107659 0.0311809  0.03131118 0.03146998
#  0.03165976 0.03188284 0.03214147 0.03243783 0.03277404 0.0331522
#  0.0335744  0.03404268 0.0345591  0.03512562 0.03574415 0.03641643
#  0.03714398 0.03781902 0.0383664  0.03880156 0.03913694 0.03938266
#  0.03954688 0.03963621 0.03965597 0.03961047 0.03950318 0.03933693
#  0.03911406 0.03883661 0.03850644 0.03812539 0.03769543 0.0372188
# ...

# %%
print(sol31.lw)
# Out:
# e-01 8.08080808e-01 8.08080808e-01 ... 8.08080808e-01
#     8.08080808e-01 8.08080808e-01]
#    [8.08080808e-01 8.08080808e-01 8.08080808e-01 ... 8.08080808e-01
#     8.08080808e-01 8.08080808e-01]
#    ...
#    [8.08080808e-01 8.08080808e-01 8.08080808e-01 ... 8.08080808e-01
#     8.08080808e-01 8.08080808e-01]
#    [8.08080808e-01 8.08080808e-01 8.08080808e-01 ... 8.08080808e-01
#     8.08080808e-01 8.08080808e-01]
#    [4.54545455e-01 4.54545455e-01 4.54545455e-01 ... 4.54545455e-01
#     4.54545455e-01 4.54545455e-01]]
#
#   [[6.96969697e-01 6.96969697e-01 6.96969697e-01 ... 6.96969697e-01
#     6.96969697e-01 6.96969697e-01]
#    [6.96969697e-01 6.96969697e-01 6.96969697e-01 ... 6.96969697e-01
#     6.96969697e-01 6.96969697e-01]
#    [6.96969697e-01 6.96969697e-01 6.96969697e-01 ... 6.96969697e-01
#     6.96969697e-01 6.96969697e-01]
#    ...
#    [6.96969697e-01 6.96969697e-01 6.96969697e-01 ... 6.96969697e-01
#     6.96969697e-01 6.96969697e-01]
# ...
